# %%
# Python 3
import emoji
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import statsmodels.api as sm
import statsmodels.formula.api as smf
from bs4 import BeautifulSoup

import unicodedata as uni
from nltk.tokenize import TweetTokenizer
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from nltk import word_tokenize
from string import punctuation


pd.set_option('display.max_columns',500)
pd.set_option('display.max_rows',500)

# %matplotlib inline
# Out:
# //anaconda/envs/capstone/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# # Goal:
# Using   the   training   data   in    ages_train.csv ,   build   a   statistical   model   to   predict   the
# age   of   users   in    ages_test.csv,     based   on   any   of   the   information   provided   (profiles, friend   networks,   and   mentions).

# %% [markdown]
# # Load data

# %%
# load json files: 
ap = pd.read_json('assignment_package/age_profiles.json')
at = pd.read_json('assignment_package/age_tweets.json')

# %%
# load csv files:
ages_train = pd.read_csv('assignment_package/ages_train.csv')
mentions = pd.read_csv('assignment_package/mentions.csv')
friends = pd.read_csv('assignment_package/friends.csv')

# %% [markdown]
# # Take a look at data

# %%
mentions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17695 entries, 0 to 17694
# Data columns (total 3 columns):
# ID                 17695 non-null int64
# MentionedID        17695 non-null int64
# MentionedHandle    17695 non-null object
# dtypes: int64(2), object(1)
# memory usage: 414.8+ KB

# %%
mentions.head()
# Out:
#           ID  MentionedID MentionedHandle
# 0  612815277    798747864    AlenaBacalia
# 1  612815277    354590068      hfholden34
# 2  612815277    401111769   MarilynYousif
# 3  612815277     35581752      heeeeyerin
# 4  612815277   1591956090      DogeTheDog

# %%
friends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46609 entries, 0 to 46608
# Data columns (total 2 columns):
# ID          46609 non-null int64
# FriendID    46609 non-null int64
# dtypes: int64(2)
# memory usage: 728.3 KB

# %%
friends.head()
# Out:
#           ID   FriendID
# 0  612815277  574147452
# 1  612815277   36767299
# 2  612815277   29374598
# 3  612815277   67634814
# 4  612815277   30008146

# %%
ages_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1711 entries, 0 to 1710
# Data columns (total 2 columns):
# ID     1711 non-null int64
# Age    1711 non-null int64
# dtypes: int64(2)
# memory usage: 26.8 KB

# %%
ages_train.head()
# Out:
#           ID  Age
# 0   23605717   21
# 1  781084760   19
# 2  102262916   21
# 3  413710015   21
# 4  584304916   90

# %%
ap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2410 entries, 0 to 2409
# Data columns (total 41 columns):
# contributors_enabled                  2410 non-null bool
# created_at                            2410 non-null datetime64[ns]
# default_profile                       2410 non-null bool
# default_profile_image                 2410 non-null bool
# description                           2410 non-null object
# entities                              2410 non-null object
# favourites_count                      2410 non-null int64
# follow_request_sent                   2410 non-null bool
# followers_count                       2410 non-null int64
# following                             2410 non-null bool
# friends_count                         2410 non-null int64
# geo_enabled                           2410 non-null bool
# id                                    2410 non-null int64
# id_str                                2410 non-null int64
# is_translation_enabled                2410 non-null bool
# is_translator                         2410 non-null bool
# lang                                  2410 non-null object
# listed_count                          2410 non-null int64
# location                              2410 non-null object
# name                                  2410 non-null object
# notifications                         2410 non-null bool
# profile_background_color              2410 non-null object
# profile_background_image_url          2410 non-null object
# profile_background_image_url_https    2410 non-null object
# profile_background_tile               2410 non-null bool
# profile_banner_url                    2191 non-null object
# profile_image_url                     2410 non-null object
# profile_image_url_https               2410 non-null object
# profile_link_color                    2410 non-null object
# profile_sidebar_border_color          2410 non-null object
# profile_sidebar_fill_color            2410 non-null object
# profile_text_color                    2410 non-null object
# profile_use_background_image          2410 non-null bool
# protected                             2410 non-null bool
# screen_name                           2410 non-null object
# status                                2373 non-null object
# statuses_count                        2410 non-null int64
# time_zone                             1697 non-null object
# url                                   550 non-null object
# utc_offset                            1697 non-null float64
# verified                              2410 non-null bool
# dtypes: bool(13), datetime64[ns](1), float64(1), int64(7), object(19)
# memory usage: 576.6+ KB

# %%
ap.head()
# Out:
#    contributors_enabled          created_at  default_profile  \
# 0                 False 2012-06-19 17:54:58            False
# 1                 False 2012-02-12 22:36:17            False
# 2                 False 2011-03-11 21:44:56            False
# 3                 False 2009-12-17 20:08:55            False
# 4                 False 2011-03-24 21:14:53            False
#
#    default_profile_image                                        description  \
# 0                  False             You'll never find another one like me.
# 1                  False  If you like me, i probably like you more. {IG:...
# 2                  False          Success doesn’t come to you…you go to it.
# 3                  False  NEVER care about what a person says that doesn...
# 4                  False  these niggas some haters & i made myself so ea...
#
#                         entities  favourites_count  follow_request_sent  \
# 0  {'description': {'urls': []}}              7931                False
# 1  {'description': {'urls': []}}              1141                False
# 2  {'description': {'urls': []}}               174                False
# 3  {'description': {'urls': []}}               303                False
# 4  {'description': {'urls': []}}                52                False
#
#    followers_count  following  friends_count  geo_enabled         id  \
# 0              274      False            264         True  612815277
# 1              481      False            527         True  490791079
# 2              878      False            953        False  264416315
# 3              742      False            701        False   97515432
# 4              729      False            688        False  271608323
#
#       id_str  is_translation_enabled  is_translator lang  listed_count  \
# 0  612815277                   False          False   en             1
# 1  490791079                   False          False   en             1
# 2  264416315                   False          False   en             2
# 3   97515432                   False          False   en            30
# 4  271608323                   False          False   en             0
#
#                 location          name  notifications  \
# 0                               Greggy          False
# 1                 9⃣3⃣7⃣        Guff✌️          False
# 2            Wonderland   Starqueria.⚓          False
# 3  •Carolina South• 843•   . keeleesha          False
# 4       Seven•five•Seven   killakee :)          False
#
#   profile_background_color                       profile_background_image_url  \
# 0                   131516  http://abs.twimg.com/images/themes/theme14/bg.gif
# 1                   1A1B1F   http://abs.twimg.com/images/themes/theme9/bg.gif
# 2                   FCEBB6  http://pbs.twimg.com/profile_background_images...
# 3                   131516  http://pbs.twimg.com/profile_background_images...
# 4                   0A0A0A  http://pbs.twimg.com/profile_background_images...
#
#                   profile_background_image_url_https  profile_background_tile  \
# 0  https://abs.twimg.com/images/themes/theme14/bg...                     True
# 1  https://abs.twimg.com/images/themes/theme9/bg.gif                    False
# 2  https://pbs.twimg.com/profile_background_image...                     True
# 3  https://pbs.twimg.com/profile_background_image...                     True
# 4  https://pbs.twimg.com/profile_background_image...                     True
#
#                                   profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/61281527...
# 1  https://pbs.twimg.com/profile_banners/49079107...
# 2  https://pbs.twimg.com/profile_banners/26441631...
# 3                                                NaN
# 4  https://pbs.twimg.com/profile_banners/27160832...
#
#                                    profile_image_url  \
# 0  http://pbs.twimg.com/profile_images/4776662828...
# 1  http://pbs.twimg.com/profile_images/5097227545...
# 2  http://pbs.twimg.com/profile_images/5127311352...
# 3  http://pbs.twimg.com/profile_images/4939742059...
# 4  http://pbs.twimg.com/profile_images/4627093362...
#
#                              profile_image_url_https profile_link_color  \
# 0  https://pbs.twimg.com/profile_images/477666282...             009999
# 1  https://pbs.twimg.com/profile_images/509722754...             2FC2EF
# 2  https://pbs.twimg.com/profile_images/512731135...             CE7834
# 3  https://pbs.twimg.com/profile_images/493974205...             009999
# 4  https://pbs.twimg.com/profile_images/462709336...             D62D0F
#
#   profile_sidebar_border_color profile_sidebar_fill_color profile_text_color  \
# 0                       EEEEEE                     EFEFEF             333333
# 1                       181A1E                     252429             666666
# 2                       F0A830                     78C0A8             5E412F
# 3                       FFFFFF                     EFEFEF             333333
# 4                       000000                     000000             A3A3A3
#
#    profile_use_background_image  protected      screen_name  \
# 0                          True      False  agregtoremember
# 1                          True      False       C_Guffieee
# 2                          True      False      _Starqueria
# 3                          True      False        Keeleesha
# 4                          True      False      KeeLashawn_
#
#                                               status  statuses_count  \
# 0  {'retweeted_status': {'retweet_count': 452, 'c...           12230
# 1  {'retweet_count': 0, 'created_at': 'Fri Sep 26...           14680
# 2  {'retweeted_status': {'retweet_count': 2614, '...           22857
# 3  {'retweet_count': 0, 'entities': {'urls': [], ...           71654
# 4  {'retweet_count': 0, 'entities': {'urls': [{'e...           48452
#
#                     time_zone   url  utc_offset  verified
# 0      Atlantic Time (Canada)  None    -10800.0     False
# 1                      Hawaii  None    -36000.0     False
# 2                      Hawaii  None    -36000.0     False
# 3  Eastern Time (US & Canada)  None    -14400.0     False
# 4  Eastern Time (US & Canada)  None    -14400.0     False

# %%
at.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28138 entries, 0 to 28137
# Data columns (total 25 columns):
# contributors                 0 non-null float64
# coordinates                  1298 non-null object
# created_at                   28138 non-null datetime64[ns]
# entities                     28138 non-null object
# favorite_count               28138 non-null int64
# favorited                    28138 non-null bool
# geo                          1298 non-null object
# id                           28138 non-null int64
# id_str                       28138 non-null int64
# in_reply_to_screen_name      5299 non-null object
# in_reply_to_status_id        4839 non-null float64
# in_reply_to_status_id_str    4839 non-null float64
# in_reply_to_user_id          5299 non-null float64
# in_reply_to_user_id_str      5299 non-null float64
# lang                         28138 non-null object
# metadata                     28138 non-null object
# place                        1341 non-null object
# possibly_sensitive           8168 non-null float64
# retweet_count                28138 non-null int64
# retweeted                    28138 non-null bool
# retweeted_status             7645 non-null object
# source                       28138 non-null object
# text                         28138 non-null object
# truncated                    28138 non-null bool
# user                         28138 non-null object
# dtypes: bool(3), datetime64[ns](1), float64(6), int64(4), object(11)
# memory usage: 5.0+ MB

# %%
at.head()
# Out:
#    contributors coordinates          created_at  \
# 0           NaN        None 2014-09-26 05:55:45
# 1           NaN        None 2014-09-26 05:58:17
# 2           NaN        None 2014-09-26 05:59:47
# 3           NaN        None 2014-09-26 06:00:07
# 4           NaN        None 2014-09-26 08:09:57
#
#                                             entities  favorite_count  \
# 0  {'hashtags': [], 'urls': [], 'symbols': [], 'u...               0
# 1  {'hashtags': [], 'urls': [], 'symbols': [], 'u...               0
# 2  {'hashtags': [], 'urls': [], 'symbols': [], 'u...               1
# 3  {'hashtags': [], 'urls': [], 'symbols': [], 'u...               1
# 4  {'hashtags': [], 'urls': [], 'symbols': [], 'u...               1
#
#    favorited   geo                  id              id_str  \
# 0      False  None  515379174454747136  515379174454747136
# 1      False  None  515379813670854656  515379813670854656
# 2      False  None  515380190361288704  515380190361288704
# 3      False  None  515380273005854721  515380273005854720
# 4      False  None  515412946608852992  515412946608852992
#
#   in_reply_to_screen_name  in_reply_to_status_id  in_reply_to_status_id_str  \
# 0                    None                    NaN                        NaN
# 1                    None                    NaN                        NaN
# 2                    None                    NaN                        NaN
# 3                    None                    NaN                        NaN
# 4                    None                    NaN                        NaN
#
#    in_reply_to_user_id  in_reply_to_user_id_str lang  \
# 0                  NaN                      NaN   en
# 1                  NaN                      NaN   en
# 2                  NaN                      NaN   en
# 3                  NaN                      NaN   en
# 4                  NaN                      NaN   en
#
#                                             metadata place  \
# 0  {'result_type': 'recent', 'iso_language_code':...  None
# 1  {'result_type': 'recent', 'iso_language_code':...  None
# 2  {'result_type': 'recent', 'iso_language_code':...  None
# 3  {'result_type': 'recent', 'iso_language_code':...  None
# 4  {'result_type': 'recent', 'iso_language_code':...  None
#
#    possibly_sensitive  retweet_count  retweeted  \
# 0                 NaN              7      False
# 1                 NaN             80      False
# 2                 NaN              1      False
# 3                 NaN              0      False
# 4                 NaN              0      False
#
#                                     retweeted_status  \
# 0  {'in_reply_to_status_id': None, 'coordinates':...
# 1  {'in_reply_to_status_id': None, 'coordinates':...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/android" ...
#
#                                                 text  truncated  \
# 0  RT @AlenaBacalia: i over think and second gues...      False
# 1  RT @hfholden34: I've wasted too much time on t...      False
# 2                                  I'm already gone.      False
# 3  I'm already something to someone that I don't ...      False
# 4  I don't know what I'm doing with my life, but ...      False
#
#                                                 user
# 0  {'follow_request_sent': False, 'profile_image_...
# 1  {'follow_request_sent': False, 'profile_image_...
# 2  {'follow_request_sent': False, 'profile_image_...
# 3  {'follow_request_sent': False, 'profile_image_...
# 4  {'follow_request_sent': False, 'profile_image_...

# %% [markdown]
# # First Iteration: Use all numeric variables to fit a linear regression model

# %%
def extract_emojis(s):
    return ''.join(c for c in str(s) if c in emoji.UNICODE_EMOJI)

def age_profiles_prep(age_profiles):
    '''Process age_profiles for modeling'''
    ap_new = pd.concat([age_profiles,
                        pd.DataFrame(age_profiles['status'].apply(pd.Series) \
                        .rename(columns = lambda x: 'status_' + str(x)))], axis=1)
    ap_new['status_emoji'] = ap_new['status_text'].map(lambda x: extract_emojis(x))
    ap_new['has_emoji'] = ap_new['status_emoji'].map(lambda x: int(x != ''))
    ap_new['emoji_cnt'] = ap_new['status_emoji'].map(lambda x: len(x))
    return ap_new

# %%
def joined_age(ap_new, ages_train):
    ap_new = ap_new.set_index('id')
    ages_train = ages_train.set_index('ID')
    age_joined = ap_new.join(ages_train, how='inner')
    return age_joined

# %%
ap_new = age_profiles_prep(ap)
# Out:
# //anaconda/envs/capstone/lib/python3.6/site-packages/pandas/core/indexes/api.py:43: RuntimeWarning: '>' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   union = _union_indexes(indexes)
# //anaconda/envs/capstone/lib/python3.6/site-packages/pandas/core/indexes/api.py:77: RuntimeWarning: '>' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   result = result.union(other)

# %%
ap_new['source_parsed'] = ap_new['status_source'].apply(lambda x: BeautifulSoup(str(x),'html.parser').text)

# %%
# define ios devices:
ios = ['Twitter for iPhone', 'Twitter for iPad', 'iOS', 'Twitter for Mac', 'Tweetbot for Mac',
       'TweetCaster for iOS', 'Tweetbot for iΟS', 'Osfoora for iOS', 'UberSocial for iPhone', 'OS X',
       'Instagram on iOS', '8 Ball Pool™ on iOS', 'Photos on iOS']

# %%
# define Android devices:
android = ['Twitter for Android', 'TweetCaster for Android', 'Plume for Android',
          'Twitter for Android Tablets', 'Twitter for  Android', 'UberSocial for Android',
          'Vine for Android', 'Fenix for Android', 'Echofon  Android']

# %%
# create a new column as source_ios, in order to get proportion
ap_new['source_ios'] = (ap_new['source_parsed'].isin(ios)).astype(int)
ap_new['source_android'] = (ap_new['source_parsed'].isin(android)).astype(int)

# %%
age_joined = joined_age(ap_new, ages_train)

# %% [markdown]
# #### ages_train dataset has 1711 user IDs, age_profiles has 2410 users IDs, after inner join with age_profiles, return 1688 user IDs.

# %%
age_joined.describe()
# Out:
#        favourites_count  followers_count  friends_count        id_str  \
# count       1688.000000      1688.000000    1688.000000  1.688000e+03
# mean        1769.623223       989.703199     745.468602  6.863965e+08
# std         4048.312684      8096.493864    5913.824414  8.022633e+08
# min            0.000000         0.000000     -69.000000  2.025381e+06
# 25%           99.750000       160.750000     176.750000  1.442114e+08
# 50%          546.000000       347.000000     338.000000  3.384143e+08
# 75%         1880.250000       702.250000     614.250000  8.548117e+08
# max        99169.000000    258937.000000  202293.000000  2.832494e+09
#
#        listed_count  statuses_count    utc_offset  status_contributors  \
# count   1688.000000      1688.00000   1187.000000                  0.0
# mean       5.848341     17187.82109 -12522.662174                  NaN
# std       40.450173     25403.11617  15030.538346                  NaN
# min        0.000000         0.00000 -39600.000000                  NaN
# 25%        0.000000      2080.75000 -18000.000000                  NaN
# 50%        1.000000      7746.50000 -18000.000000                  NaN
# 75%        3.000000     21482.75000 -10800.000000                  NaN
# max     1292.000000    257590.00000  43200.000000                  NaN
#
#        status_favorite_count     status_id  status_in_reply_to_status_id  \
# count            1664.000000  1.664000e+03                  2.040000e+02
# mean                0.274038  5.147472e+17                  5.147682e+17
# std                 1.026128  2.487937e+15                  2.582377e+15
# min                 0.000000  4.914759e+17                  4.912976e+17
# 25%                 0.000000  5.151386e+17                  5.151718e+17
# 50%                 0.000000  5.154432e+17                  5.154378e+17
# 75%                 0.000000  5.155501e+17                  5.155525e+17
# max                23.000000  5.155829e+17                  5.155821e+17
#
#        status_in_reply_to_user_id  status_retweet_count  status_0  \
# count                2.430000e+02           1664.000000       0.0
# mean                 6.411431e+08            305.992788       NaN
# std                  7.675660e+08           2136.013252       NaN
# min                  8.771022e+06              0.000000       NaN
# 25%                  1.424379e+08              0.000000       NaN
# 50%                  3.309488e+08              0.000000       NaN
# 75%                  8.055676e+08              1.000000       NaN
# max                  2.785766e+09          40111.000000       NaN
#
#          has_emoji    emoji_cnt   source_ios  source_android          Age
# count  1688.000000  1688.000000  1688.000000     1688.000000  1688.000000
# mean      0.261848     0.592417     0.526066        0.188981    22.214455
# std       0.439771     2.226049     0.499468        0.391610     7.244988
# min       0.000000     0.000000     0.000000        0.000000    18.000000
# 25%       0.000000     0.000000     0.000000        0.000000    19.000000
# 50%       0.000000     0.000000     1.000000        0.000000    21.000000
# 75%       1.000000     1.000000     1.000000        0.000000    22.000000
# max       1.000000    74.000000     1.000000        1.000000   111.000000

# %%
scatter_matrix(age_joined[['emoji_cnt','statuses_count','friends_count','followers_count',
                        'favourites_count','listed_count','Age']], alpha=.5, figsize=(10, 10), diagonal='kde');

# %%
# Length of user profile description?
age_joined['description_length'] = age_joined['description'].apply(lambda x: len(x))

# %% [markdown]
# -  length of description seems not that different across age

# %% [markdown]
# - How user identify location might have signal. (Natural language processing). But hard to extract in a short period of time.

# %%
# profile_background_tile: seems not that different across ages
plt.scatter(age_joined['Age'], age_joined['profile_background_tile'])
plt.xlabel('age')
plt.ylabel('inspect feature')

# %%
age_joined['profile_use_background_image'].value_counts()
# Out:
# True     1584
# False     104
# Name: profile_use_background_image, dtype: int64

# %%
age_joined['protected'].value_counts()
# Out:
# False    1665
# True       23
# Name: protected, dtype: int64

# %%
age_joined['source_parsed'] = age_joined['status_source'].apply(lambda x: BeautifulSoup(str(x),'html.parser').text)

# %%
# create a new column as age_decade:
bins = [17,25,35,45,55,120]
group_names = ['18-25','26-35','36-45','46-55','>55']
age_joined['age_decade'] = pd.cut(age_joined['Age'], bins, labels=group_names)

# %%
age_joined.head()
# Out:
#            contributors_enabled          created_at  default_profile  \
# 612815277                 False 2012-06-19 17:54:58            False
# 490791079                 False 2012-02-12 22:36:17            False
# 264416315                 False 2011-03-11 21:44:56            False
# 97515432                  False 2009-12-17 20:08:55            False
# 224078321                 False 2010-12-08 02:50:16            False
#
#            default_profile_image  \
# 612815277                  False
# 490791079                  False
# 264416315                  False
# 97515432                   False
# 224078321                  False
#
#                                                  description  \
# 612815277             You'll never find another one like me.
# 490791079  If you like me, i probably like you more. {IG:...
# 264416315          Success doesn’t come to you…you go to it.
# 97515432   NEVER care about what a person says that doesn...
# 224078321                                          STOP PREE
#
#                                 entities  favourites_count  \
# 612815277  {'description': {'urls': []}}              7931
# 490791079  {'description': {'urls': []}}              1141
# 264416315  {'description': {'urls': []}}               174
# 97515432   {'description': {'urls': []}}               303
# 224078321  {'description': {'urls': []}}              1188
#
#            follow_request_sent  followers_count  following  friends_count  \
# 612815277                False              274      False            264
# 490791079                False              481      False            527
# 264416315                False              878      False            953
# 97515432                 False              742      False            701
# 224078321                False             1030      False           1006
#
#            geo_enabled     id_str  is_translation_enabled  is_translator lang  \
# 612815277         True  612815277                   False          False   en
# 490791079         True  490791079                   False          False   en
# 264416315        False  264416315                   False          False   en
# 97515432         False   97515432                   False          False   en
# 224078321         True  224078321                   False          False   en
#
#            listed_count               location          name  notifications  \
# 612815277             1                               Greggy          False
# 490791079             1                 9⃣3⃣7⃣        Guff✌️          False
# 264416315             2            Wonderland   Starqueria.⚓          False
# 97515432             30  •Carolina South• 843•   . keeleesha          False
# 224078321             3                     ME         King.          False
#
#           profile_background_color  \
# 612815277                   131516
# 490791079                   1A1B1F
# 264416315                   FCEBB6
# 97515432                    131516
# 224078321                   642D8B
#
#                                 profile_background_image_url  \
# 612815277  http://abs.twimg.com/images/themes/theme14/bg.gif
# 490791079   http://abs.twimg.com/images/themes/theme9/bg.gif
# 264416315  http://pbs.twimg.com/profile_background_images...
# 97515432   http://pbs.twimg.com/profile_background_images...
# 224078321  http://pbs.twimg.com/profile_background_images...
#
#                           profile_background_image_url_https  \
# 612815277  https://abs.twimg.com/images/themes/theme14/bg...
# 490791079  https://abs.twimg.com/images/themes/theme9/bg.gif
# 264416315  https://pbs.twimg.com/profile_background_image...
# 97515432   https://pbs.twimg.com/profile_background_image...
# 224078321  https://pbs.twimg.com/profile_background_image...
#
#            profile_background_tile  \
# 612815277                     True
# 490791079                    False
# 264416315                     True
# 97515432                      True
# 224078321                     True
#
#                                           profile_banner_url  \
# 612815277  https://pbs.twimg.com/profile_banners/61281527...
# 490791079  https://pbs.twimg.com/profile_banners/49079107...
# 264416315  https://pbs.twimg.com/profile_banners/26441631...
# 97515432                                                 NaN
# 224078321  https://pbs.twimg.com/profile_banners/22407832...
#
#                                            profile_image_url  \
# 612815277  http://pbs.twimg.com/profile_images/4776662828...
# 490791079  http://pbs.twimg.com/profile_images/5097227545...
# 264416315  http://pbs.twimg.com/profile_images/5127311352...
# 97515432   http://pbs.twimg.com/profile_images/4939742059...
# 224078321  http://pbs.twimg.com/profile_images/5136981503...
#
#                                      profile_image_url_https  \
# 612815277  https://pbs.twimg.com/profile_images/477666282...
# 490791079  https://pbs.twimg.com/profile_images/509722754...
# 264416315  https://pbs.twimg.com/profile_images/512731135...
# 97515432   https://pbs.twimg.com/profile_images/493974205...
# 224078321  https://pbs.twimg.com/profile_images/513698150...
#
#           profile_link_color profile_sidebar_border_color  \
# 612815277             009999                       EEEEEE
# 490791079             2FC2EF                       181A1E
# 264416315             CE7834                       F0A830
# 97515432              009999                       FFFFFF
# 224078321             FF0091                       FFFFFF
#
#           profile_sidebar_fill_color profile_text_color  \
# 612815277                     EFEFEF             333333
# 490791079                     252429             666666
# 264416315                     78C0A8             5E412F
# 97515432                      EFEFEF             333333
# 224078321                     DDEEF6             333333
#
#            profile_use_background_image  protected      screen_name  \
# 612815277                          True      False  agregtoremember
# 490791079                          True      False       C_Guffieee
# 264416315                          True      False      _Starqueria
# 97515432                           True      False        Keeleesha
# 224078321                          True      False   loook_backatit
#
#                                                       status  statuses_count  \
# 612815277  {'retweeted_status': {'retweet_count': 452, 'c...           12230
# 490791079  {'retweet_count': 0, 'created_at': 'Fri Sep 26...           14680
# 264416315  {'retweeted_status': {'retweet_count': 2614, '...           22857
# 97515432   {'retweet_count': 0, 'entities': {'urls': [], ...           71654
# 224078321  {'retweet_count': 0, 'created_at': 'Fri Sep 26...           19888
#
#                             time_zone   url  utc_offset  verified  \
# 612815277      Atlantic Time (Canada)  None    -10800.0     False
# 490791079                      Hawaii  None    -36000.0     False
# 264416315                      Hawaii  None    -36000.0     False
# 97515432   Eastern Time (US & Canada)  None    -14400.0     False
# 224078321                       Quito  None    -18000.0     False
#
#            status_contributors status_coordinates  \
# 612815277                  NaN               None
# 490791079                  NaN               None
# 264416315                  NaN               None
# 97515432                   NaN               None
# 224078321                  NaN               None
#
#                         status_created_at  \
# 612815277  Fri Sep 26 16:49:37 +0000 2014
# 490791079  Fri Sep 26 17:42:07 +0000 2014
# 264416315  Fri Sep 26 02:57:32 +0000 2014
# 97515432   Fri Sep 26 19:10:42 +0000 2014
# 224078321  Fri Sep 26 13:08:25 +0000 2014
#
#                                              status_entities  \
# 612815277  {'urls': [], 'user_mentions': [{'id': 15919560...
# 490791079  {'urls': [], 'user_mentions': [], 'symbols': [...
# 264416315  {'urls': [], 'media': [{'media_url': 'http://p...
# 97515432   {'urls': [], 'media': [{'media_url': 'http://p...
# 224078321  {'urls': [], 'user_mentions': [], 'symbols': [...
#
#            status_favorite_count status_favorited status_geo     status_id  \
# 612815277                    0.0            False       None  5.155437e+17
# 490791079                    0.0            False       None  5.155569e+17
# 264416315                    0.0            False       None  5.153343e+17
# 97515432                     0.0            False       None  5.155792e+17
# 224078321                    0.0            False       None  5.154881e+17
#
#                 status_id_str status_in_reply_to_screen_name  \
# 612815277  515543724785684480                           None
# 490791079  515556938512609280                           None
# 264416315  515334328113307649                           None
# 97515432   515579231393562624                           None
# 224078321  515488059371311104                           None
#
#            status_in_reply_to_status_id status_in_reply_to_status_id_str  \
# 612815277                           NaN                             None
# 490791079                           NaN                             None
# 264416315                           NaN                             None
# 97515432                            NaN                             None
# 224078321                           NaN                             None
#
#            status_in_reply_to_user_id status_in_reply_to_user_id_str  \
# 612815277                         NaN                           None
# 490791079                         NaN                           None
# 264416315                         NaN                           None
# 97515432                          NaN                           None
# 224078321                         NaN                           None
#
#           status_lang status_place status_possibly_sensitive  \
# 612815277          en         None                       NaN
# 490791079          en         None                       NaN
# 264416315          en         None                     False
# 97515432           en         None                     False
# 224078321          en         None                       NaN
#
#            status_retweet_count status_retweeted  \
# 612815277                 452.0            False
# 490791079                   0.0            False
# 264416315                2614.0            False
# 97515432                    0.0            False
# 224078321                   0.0            False
#
#                                      status_retweeted_status  \
# 612815277  {'retweet_count': 452, 'created_at': 'Fri Sep ...
# 490791079                                                NaN
# 264416315  {'retweet_count': 2614, 'entities': {'urls': [...
# 97515432                                                 NaN
# 224078321                                                NaN
#
#                                                status_source  \
# 612815277  <a href="http://twitter.com/download/android" ...
# 490791079  <a href="http://twitter.com/download/iphone" r...
# 264416315  <a href="http://twitter.com/download/android" ...
# 97515432   <a href="http://www.myplume.com/" rel="nofollo...
# 224078321  <a href="http://twitter.com/download/android" ...
#
#                                                  status_text status_truncated  \
# 612815277  RT @DogeTheDog: Wow\n           So friday\n   ...            False
# 490791079  Damn I gotta wait to next week to get the IPho...            False
# 264416315  RT @ImNeverChillin: How your girl look at you ...            False
# 97515432   his cake I got for his daycare class. They tor...            False
# 224078321  Bae got like 2-3 more mnths in jail #freemyboo...            False
#
#            status_0 status_emoji  has_emoji  emoji_cnt        source_parsed  \
# 612815277       NaN                       0          0  Twitter for Android
# 490791079       NaN            😒          1          1   Twitter for iPhone
# 264416315       NaN                       0          0  Twitter for Android
# 97515432        NaN                       0          0    Plume for Android
# 224078321       NaN                       0          0  Twitter for Android
#
#            source_ios  source_android  Age  description_length age_decade
# 612815277           0               1   21                  38      18-25
# 490791079           1               0   18                  56      18-25
# 264416315           0               1   18                  41      18-25
# 97515432            0               0   23                  97      18-25
# 224078321           0               1   18                   9      18-25

# %%
age_joined.groupby('age_decade')['Age'].count()
# Out:
# age_decade
# 18-25    1488
# 26-35     136
# 36-45      36
# 46-55      13
# >55        15
# Name: Age, dtype: int64

# %%
age_joined.groupby('age_decade')['Age'].count().plot(kind='bar',alpha=.7)
plt.title('Age group vs. Number of users')

# %%
age_joined.groupby('age_decade')['source_android'].sum()
# Out:
# age_decade
# 18-25    288
# 26-35     20
# 36-45      7
# 46-55      3
# >55        1
# Name: source_android, dtype: int64

# %%
age_joined.groupby('age_decade')['source_ios'].sum()
# Out:
# age_decade
# 18-25    800
# 26-35     61
# 36-45     14
# 46-55      3
# >55       10
# Name: source_ios, dtype: int64

# %%
age_joined.groupby('age_decade')['favourites_count'].mean()
# Out:
# age_decade
# 18-25    1907.367608
# 26-35     509.897059
# 36-45     518.194444
# 46-55    1714.000000
# >55      2578.533333
# Name: favourites_count, dtype: float64

# %%
age_joined.groupby('age_decade')['followers_count'].mean()
# Out:
# age_decade
# 18-25    1024.581989
# 26-35     705.338235
# 36-45     330.305556
# 46-55     334.230769
# >55      2258.600000
# Name: followers_count, dtype: float64

# %% [markdown]
# ## Intital guesses about tweets text:
# 1. use # or not
# 2. which # are they using
# 3. mention people or not
# 4. who are they mentioning, age of the people they are mentioning
# 5. use emoji or not
# 6. how many emojis are they using
# 7. which emoji are they using -- emoji as categorical variables
# 8. words in tweets. e.g. TGIF, thank god it's friday, lmao, etc.
# 9. punctuations in tweets
# 10. sentiment in tweets

# %%
age_joined['is_18_25'] = age_joined['age_decade'].map(lambda x: x == '18-25')

# %%
age_joined['is_18_25'].value_counts()
# imbalanced class!
# Out:
# True     1488
# False     200
# Name: is_18_25, dtype: int64

# %%
age_joined['has_description'] = age_joined['description'].map(lambda x: x != '')

# %%
age_joined.groupby('is_18_25')['has_description'].sum()/age_joined.groupby('is_18_25')['has_description'].count()
# no signal
# Out:
# is_18_25
# False    0.865000
# True     0.872312
# Name: has_description, dtype: float64

# %%
# create 2 dataframes to inspect the difference between the age groups:
old_group = age_joined[age_joined['is_18_25'] == False]
young_group = age_joined[age_joined['is_18_25'] == True]

# %%
old_group.head()
# Out:
#             contributors_enabled          created_at  default_profile  \
# 40604337                   False 2009-05-17 04:03:18            False
# 2718214807                 False 2014-08-08 23:24:43             True
# 559747070                  False 2012-04-21 17:49:48             True
# 134965175                  False 2010-04-19 23:56:07            False
# 393621283                  False 2011-10-18 20:27:33             True
#
#             default_profile_image  \
# 40604337                    False
# 2718214807                  False
# 559747070                   False
# 134965175                   False
# 393621283                   False
#
#                                                   description  \
# 40604337                                instagram tyshanna 29
# 2718214807  if today was my birthday i would want a taco b...
# 559747070   Jazztronics at Liberty 2011 - Cosmopolitan Pig...
# 134965175   i like the strokes, gym, working on my tan, be...
# 393621283   I repair Musical Instruments at St Johns Music...
#
#                                                      entities  \
# 40604337                        {'description': {'urls': []}}
# 2718214807  {'description': {'urls': []}, 'url': {'urls': ...
# 559747070   {'description': {'urls': []}, 'url': {'urls': ...
# 134965175                       {'description': {'urls': []}}
# 393621283                       {'description': {'urls': []}}
#
#             favourites_count  follow_request_sent  followers_count  following  \
# 40604337                 412                False              205      False
# 2718214807                59                False               15      False
# 559747070                 17                False               14      False
# 134965175               1487                False              922      False
# 393621283                209                False               41      False
#
#             friends_count  geo_enabled      id_str  is_translation_enabled  \
# 40604337              230         True    40604337                   False
# 2718214807             93        False  2718214807                   False
# 559747070              21         True   559747070                   False
# 134965175            1085         True   134965175                   False
# 393621283              81         True   393621283                   False
#
#             is_translator lang  listed_count              location  \
# 40604337            False   en             0       Bronx new York
# 2718214807          False   en             0               America
# 559747070           False   en             0  london forest hill
# 134965175           False   en             3                London
# 393621283           False   en             0            Calgary AB
#
#                           name  notifications profile_background_color  \
# 40604337     tyshanna deleston          False                   1A1B1F
# 2718214807               Brian          False                   C0DEED
# 559747070         Wayne Taylor          False                   C0DEED
# 134965175               maggie          False                   20201E
# 393621283   Nathaniel Metcalfe          False                   C0DEED
#
#                                  profile_background_image_url  \
# 40604337     http://abs.twimg.com/images/themes/theme9/bg.gif
# 2718214807   http://abs.twimg.com/images/themes/theme1/bg.png
# 559747070    http://abs.twimg.com/images/themes/theme1/bg.png
# 134965175   http://pbs.twimg.com/profile_background_images...
# 393621283    http://abs.twimg.com/images/themes/theme1/bg.png
#
#                            profile_background_image_url_https  \
# 40604337    https://abs.twimg.com/images/themes/theme9/bg.gif
# 2718214807  https://abs.twimg.com/images/themes/theme1/bg.png
# 559747070   https://abs.twimg.com/images/themes/theme1/bg.png
# 134965175   https://pbs.twimg.com/profile_background_image...
# 393621283   https://abs.twimg.com/images/themes/theme1/bg.png
#
#             profile_background_tile  \
# 40604337                      False
# 2718214807                    False
# 559747070                     False
# 134965175                     False
# 393621283                     False
#
#                                            profile_banner_url  \
# 40604337    https://pbs.twimg.com/profile_banners/40604337...
# 2718214807  https://pbs.twimg.com/profile_banners/27182148...
# 559747070   https://pbs.twimg.com/profile_banners/55974707...
# 134965175   https://pbs.twimg.com/profile_banners/13496517...
# 393621283                                                 NaN
#
#                                             profile_image_url  \
# 40604337    http://pbs.twimg.com/profile_images/4679213711...
# 2718214807  http://pbs.twimg.com/profile_images/4978981967...
# 559747070   http://pbs.twimg.com/profile_images/5144103387...
# 134965175   http://pbs.twimg.com/profile_images/5110401840...
# 393621283   http://pbs.twimg.com/profile_images/1599504350...
#
#                                       profile_image_url_https  \
# 40604337    https://pbs.twimg.com/profile_images/467921371...
# 2718214807  https://pbs.twimg.com/profile_images/497898196...
# 559747070   https://pbs.twimg.com/profile_images/514410338...
# 134965175   https://pbs.twimg.com/profile_images/511040184...
# 393621283   https://pbs.twimg.com/profile_images/159950435...
#
#            profile_link_color profile_sidebar_border_color  \
# 40604337               F00C2B                       D9B17E
# 2718214807             0084B4                       C0DEED
# 559747070              0084B4                       C0DEED
# 134965175              897856                       C8A867
# 393621283              0084B4                       C0DEED
#
#            profile_sidebar_fill_color profile_text_color  \
# 40604337                       EADEAA             333333
# 2718214807                     DDEEF6             333333
# 559747070                      DDEEF6             333333
# 134965175                      20201E             C8A86F
# 393621283                      DDEEF6             333333
#
#             profile_use_background_image  protected   screen_name  \
# 40604337                            True      False      tyshanna
# 2718214807                          True      False  bri_ancausey
# 559747070                           True      False    spurswayne
# 134965175                           True      False      fancyckn
# 393621283                           True      False     natrepair
#
#                                                        status  statuses_count  \
# 40604337    {'retweet_count': 0, 'entities': {'urls': [], ...             360
# 2718214807  {'retweet_count': 0, 'created_at': 'Wed Sep 24...             137
# 559747070   {'retweet_count': 0, 'entities': {'urls': [{'e...             439
# 134965175   {'retweet_count': 0, 'entities': {'urls': [{'e...            4678
# 393621283   {'retweeted_status': {'retweet_count': 2, 'cre...             456
#
#                              time_zone                     url  utc_offset  \
# 40604337                          None                    None         NaN
# 2718214807  Central Time (US & Canada)  http://t.co/vtwOQkxC2B    -18000.0
# 559747070                         None  http://t.co/r9356Nff7o         NaN
# 134965175                       London                    None      3600.0
# 393621283                         None                    None         NaN
#
#             verified  status_contributors  \
# 40604337       False                  NaN
# 2718214807     False                  NaN
# 559747070      False                  NaN
# 134965175      False                  NaN
# 393621283      False                  NaN
#
#                                            status_coordinates  \
# 40604337                                                 None
# 2718214807                                               None
# 559747070   {'coordinates': [-0.00451232, 51.54273529], 't...
# 134965175   {'coordinates': [-0.19412325, 51.49233025], 't...
# 393621283                                                None
#
#                          status_created_at  \
# 40604337    Sun Sep 21 00:01:47 +0000 2014
# 2718214807  Wed Sep 24 01:26:43 +0000 2014
# 559747070   Mon Sep 22 19:26:11 +0000 2014
# 134965175   Fri Sep 26 17:42:08 +0000 2014
# 393621283   Wed Sep 24 15:44:02 +0000 2014
#
#                                               status_entities  \
# 40604337    {'urls': [], 'media': [{'media_url': 'http://p...
# 2718214807  {'urls': [], 'user_mentions': [], 'symbols': [...
# 559747070   {'urls': [{'expanded_url': 'http://instagram.c...
# 134965175   {'urls': [{'expanded_url': 'http://online.wsj....
# 393621283   {'urls': [], 'user_mentions': [{'id': 55226877...
#
#             status_favorite_count status_favorited  \
# 40604337                      0.0            False
# 2718214807                    0.0            False
# 559747070                     0.0            False
# 134965175                     0.0            False
# 393621283                     0.0            False
#
#                                                    status_geo     status_id  \
# 40604337                                                 None  5.134782e+17
# 2718214807                                               None  5.145867e+17
# 559747070   {'coordinates': [51.54273529, -0.00451232], 't...  5.141336e+17
# 134965175   {'coordinates': [51.49233025, -0.19412325], 't...  5.155569e+17
# 393621283                                                None  5.148024e+17
#
#                  status_id_str status_in_reply_to_screen_name  \
# 40604337    513478157870333953                           None
# 2718214807  514586695090438144                           None
# 559747070   514133575495462912                           None
# 134965175   515556941817737216                           None
# 393621283   514802448264077313                           None
#
#             status_in_reply_to_status_id status_in_reply_to_status_id_str  \
# 40604337                             NaN                             None
# 2718214807                           NaN                             None
# 559747070                            NaN                             None
# 134965175                            NaN                             None
# 393621283                            NaN                             None
#
#             status_in_reply_to_user_id status_in_reply_to_user_id_str  \
# 40604337                           NaN                           None
# 2718214807                         NaN                           None
# 559747070                          NaN                           None
# 134965175                          NaN                           None
# 393621283                          NaN                           None
#
#            status_lang                                       status_place  \
# 40604337           und                                               None
# 2718214807          en                                               None
# 559747070           en  {'attributes': {}, 'id': '695b360b8171c433', '...
# 134965175           en  {'attributes': {}, 'id': '01c7ed8caf11e8b2', '...
# 393621283           en                                               None
#
#            status_possibly_sensitive  status_retweet_count status_retweeted  \
# 40604337                       False                   0.0            False
# 2718214807                       NaN                   0.0            False
# 559747070                      False                   0.0            False
# 134965175                      False                   0.0            False
# 393621283                        NaN                   2.0            False
#
#                                       status_retweeted_status  \
# 40604337                                                  NaN
# 2718214807                                                NaN
# 559747070                                                 NaN
# 134965175                                                 NaN
# 393621283   {'retweet_count': 2, 'created_at': 'Wed Sep 24...
#
#                                                 status_source  \
# 40604337    <a href="http://twitter.com/download/android" ...
# 2718214807  <a href="http://twitter.com/download/iphone" r...
# 559747070   <a href="http://instagram.com" rel="nofollow">...
# 134965175   <a href="http://twitter.com/download/iphone" r...
# 393621283   <a href="http://twitter.com/download/iphone" r...
#
#                                                   status_text  \
# 40604337                               http://t.co/R9nwkoNriu
# 2718214807                im devating if i should go to sleep
# 559747070   Done shopping at waitros Stratford @ Westfield...
# 134965175        Read slowly and often http://t.co/EjqVxrIcAy
# 393621283   RT @Kyle_Davidson_: @Hicks_206 have you heard ...
#
#            status_truncated  status_0 status_emoji  has_emoji  emoji_cnt  \
# 40604337              False       NaN                       0          0
# 2718214807            False       NaN                       0          0
# 559747070             False       NaN                       0          0
# 134965175             False       NaN                       0          0
# 393621283             False       NaN                       0          0
#
#                   source_parsed  source_ios  source_android  Age  \
# 40604337    Twitter for Android           0               1   30
# 2718214807   Twitter for iPhone           1               0   33
# 559747070             Instagram           0               0   40
# 134965175    Twitter for iPhone           1               0   34
# 393621283    Twitter for iPhone           1               0   29
#
#             description_length age_decade is_18_25  has_description
# 40604337                    21      26-35    False             True
# 2718214807                  73      26-35    False             True
# 559747070                  160      36-45    False             True
# 134965175                   80      26-35    False             True
# 393621283                  145      26-35    False             True

# %% [markdown]
# ## Get two raw strings, combine all users' tweets in two groups together, find their difference

# %%
young_tweet = young_group['status_text'].to_string()

# %%
old_tweet = old_group['status_text'].to_string()

# %%
# combine two groups together
data = [old_tweet, young_tweet]

# %%
sbs = SnowballStemmer('english')
punctuation = set(punctuation)
def my_tokenizer(text):
    return [token for token in word_tokenize(text)
            if token not in punctuation]

# %%
# fit TFIDF vectorizer
vectorizer = TfidfVectorizer(tokenizer=my_tokenizer, stop_words='english',analyzer= 'word', 
                             max_features=500, ngram_range=(1, 1))
vectors = vectorizer.fit_transform(data).toarray()
words = vectorizer.get_feature_names()

# %%
def get_top_values(lst, n, labels):
    '''
    Given a list of values, find the indices with the highest n values.
    Return the labels for each of these indices.

    Input: list, int, list
    Output: list
    '''
    return [labels[i] for i in np.argsort(lst)[-1:-n-1:-1]]

# %% [markdown]
# ## Find the difference in tweet text

# %%
print(">25 group top 100 by average tf-idf")
print(get_top_values(vectors[0], 100, words))
# Out:
# >25 group top 100 by average tf-idf
# ['...', 'rt', 'http', 'birthday', 'happy', "'s", 'good', 'just', "n't", 'amp', 'got', 'morning', 'night', "'m", 'new', 'posted', 'photo', 'know', 'hi', 'need', '2', 'love', 'ht', 'looking', 'crazy', 'jeter', '``', 'month', 'sorry', 'beautiful', 'said', 'cares', 'fo', 'nan', 'hope', 'amazing', 'nice', 'giveaway', 'ready', 'th', 'derek', 'today', 'thank', 'god', 's', 'think', 'right', 'respect', 'getting', 'breakfast', 'tomorrow', 'sleep', 'weekend', 'week', 'early', 'c', 'yes', '’', '“', 'shopping', '15', '😁', '1', 'like', 'guys', 'friend', 'm', "'ve", 'f', 'fall', 'check', 'prayers', 'wish', '\\n', 'fun', 'la', 'fifa', 'hot', '4', 'win', 'sa', 'says', 'saw', 'celebrating', 'r', 'read', 'si', 'college', 'cold', 'coffee', 'real', 'im', 'ig', 'really', 'reason', 'jesus', 'chec', 'scandal', 'send', 'remember']

# %%
print("18-25 group top 100 by average tf-idf")
print(get_top_values(vectors[1], 100, words))
# Out:
# 18-25 group top 100 by average tf-idf
# ['...', 'rt', 'http', "n't", "'s", "'m", 'birthday', 'happy', 'just', 'like', '``', 'got', '“', 'ca', 'day', 'people', 'want', 'today', 'love', 'faster', 'moving', 'pace', 'thank', 'cute', 'lol', 'need', 'best', 'nan', "''", 'followed', 'h', 'feel', 'friday', 'good', 'na', 't', 'new', 'work', 'shit', 'beautiful', 'o', 'amp', 'amazing', 'person', 'tonight', 'l4l', 'wait', 'tagsforlikes', '😍', '2', 'life', 'im', '20th', '6', 'ta', 'does', "'ve", 'time', '3', 'know', 'really', '21st', '//t', 'wan', 'miss', 'thanks', 'wish', 'u', 'start', 'god', '//', 'm', 'sleep', '18th', 'way', 'night', 'seriously', 'damn', '//t.c', 'tired', 'hate', 'girls', 'y', 'weeks', 'music', 'wo', 'baby', 'hours', 'better', 'hope', 'unfollowed', 'n', 'let', 'did', "'re", 'great', 'gon', 's', 'girl', 'house']

# %% [markdown]
# ## Find the difference in profile descriptions

# %%
description_data = [old_group['description'].to_string(), young_group['description'].to_string()]

# %%
desc_vectors = vectorizer.fit_transform(description_data).toarray()
desc_words = vectorizer.get_feature_names()

# %%
print(">25 group description data top 100 words by average tf-idf")
print(get_top_values(desc_vectors[0], 200, desc_words))
# Out:
# >25 group description data top 100 words by average tf-idf
# ['...', 'love', 'm', 'life', "'s", 'f', 'fan', "'m", 'instagram', 'loving', 'like', 'mother', 'follow', 'beautiful', 'family', 'born', 'lover', 'im', 'god', 'woman', 'old', 'loves', 'fashion', 'live', 'way', "n't", 'student', 'living', 'ig', 'girl', 'work', 'working', '1', 'writer', 'aspiring', 'c', 'just', 'b', '30', 'gallery', 'reader', 'seas', 'gamer', 'mom', 'want', 'city', 'music', 'wife', 'producer', 'engineer', 'proud', 'sports', 'years', 'bad', 'country', 'dream', 'meet', '♥', 'better', 'kids', 'married', 'blessed', 'blogger', 'marketing', 'company', 'good', '2', 'today', 'hard', 'day', 'g', 'media', 'ca', 'rights', 'laugh', 'people', 'rock', 'o', 'retired', 'canada', 'let', 'li', 'cats', 'road', 'c.e.o', 'man', 'read', 'nurse', 'daughter', 'lady', 'business', 'night', 'nigga', 'nice', 'nerd', 'say', 'brother', 'broadcast', 'fear', 'employed', 'miss', 'dancing', 'na', 'count', 'personality', 'photographer', 'pirate', 'place', 'passion', 'play', 'college', 'little', 'party', 'p', 'chicago', 'owner', 'cheerleader', 'neck', 'need', 'new', 'check', 'does', 'public', 'punk', 'mommy', 'ceo', 'dancer', 'r', 'raised', 'oh', '❤️', 'marine', 'second', 'turn', '21.', 'true', 'travel', 'town', 'happy', 'think', 'things', 'therandysteel', 'thank', 'th', 'heart', '26', '4', '\\ngod', 'books', '\\r', 'actually', 'happiness', 'tweets', 'home', 'hairstylist', '✨', "'ll", '♡', '♍️', 'goes', '’', 'young', '..', 'year', 'y', 'x', 'got', 'graduate', 'wan', 'w', 'visual', 'video', 't', 'tan', 'hope', 'august', 'awesome', 'jesus', 'journalist', 'softball', 'judge', 'forgive', 'beer', 'believe', 'smile', 'small', 'sister', 'singer', 'big', 'food', 'series', 'senior', 'know', 'author', 'batman', 'http', 'st', 'st.', 'insta', 'succeed']

# %%
print("18-25 group description data top 100 words by average tf-idf")
print(get_top_values(desc_vectors[1], 200, desc_words))
# Out:
# 18-25 group description data top 100 words by average tf-idf
# ['...', "'m", 'love', 'life', "n't", 'instagram', 'ig', 'just', "'s", '•', '18', 'im', 'like', 'university', 'live', 'girl', '19', '❤️', '20', 'god', 'college', '21', 'make', 'know', 'follow', 'state', 'student', 'fuck', 'dont', 'time', '//', 'living', 'future', 'good', '||', 'world', 'hate', 'music', 'old', 'l', "'re", 'got', 'people', 'heart', 'major', 'rip', 's', 'class', 'hi', 'taken', 'bitch', 'let', 'better', 'd', 'change', 'u', 'real', 'perfect', 'y', '♡', 't', 'new', 'years', 'young', 'work', "'ll", 'big', 'lover', 'want', 'fashion', 'way', '✨', 'peace', 'social', 'lo', '\\n', '2014', 'beauty', 'stay', '❤', 'queen', 'trying', 'come', 'team', 'care', 'm', 'happy', 'little', '21.', 'family', 'shit', 'c/o', 'baby', 'black', 'snapchat', 'mind', 'best', 'strong', '22', 'dance', 'forever', 'feel', 'learn', '’', 'insta', 'born', 'mommy', 'things', '♥', 'graduate', 'la', 'n', '✌', 'r.i.p', 'matter', "'18", 'journey', '✌️', 'pizza', 'aint', 'dreams', 'georgia', 'artist', "'ve", '--', 'southern', 'day', 'believe', 'bad', 'mom', 'woman', 'friends', 'senior', 'nigga', 'g', 'writer', '..', 'mother', 'proud', 'married', 'beautiful', 'ca', 'hope', 'loving', 'year', 'days', 'person', '20.', 'junior', '2nd', 'kik', 'kind', 'account', 'fullest', 'free', 'allah', 'amazing', 'leo', 'christ', 'money', 'army', 'es', 'enthusiast', 'ass', 'met', 'e', 'player', 'dead', 'livin', 'belle', 'grad', 'bio', 'amor', "'17", 'professional', 'soul', 'twitter', 'rest', 'ta', 'vibes', 'september', 'que', 'worth', 'pretty', 'tryin', 'single', 'ya', 'york', 'success', '“', '☀️', 'welcome', 'kids', 'c', 'f', 'need', 'say', 'aspiring', 'na', 'dream']

# %% [markdown]
# - From description data, we can find the words people are using is different across age groups. Thus create a new column as high_prob_25_older

# %%
older_group_word_list = ['married','producer','engineer','mother','30','family','woman','old','work','working'
                         'writer','gallery','mom','wife','kids','retired','c.e.o','nurse','lady','business','employed'
                         'photographer','mommy','ceo','hairstylist','journalist']

# %%
age_joined['older_group_words'] = age_joined['description'].apply(lambda x: any(term in x for term in older_group_word_list))

# %% [markdown]
# ## Fine the difference in emoji usage in tweets

# %%
emoji_old = ''.join(old_group[old_group['status_emoji'] != '']['status_emoji'].tolist())

# %%
emoji_young = ''.join(young_group[young_group['status_emoji'] != '']['status_emoji'].tolist())

# %%
emoji_old
# Out:
# '👯😁😘😬✌😢❤👼🍔🍔🍔✌😪📷👍💞😈😈😜😜💤💤‼💕😂🏃💨💦🙈✌😂😂😂😂😂😂😂😂😂😂😂😂😐🍴☺🍞💁😝👌😑😑😂😂😂😂😂😂💋💃💃😌😔😘👯😋🍴😀😁👌💙😁'

# %%
import collections
print(collections.Counter(emoji_old).most_common(10))
# Out:
# [('😂', 19), ('😁', 3), ('✌', 3), ('🍔', 3), ('👯', 2), ('😘', 2), ('😈', 2), ('😜', 2), ('💤', 2), ('🍴', 2)]

# %%
print(collections.Counter(emoji_young).most_common(100))
# Out:
# [('😂', 98), ('🎊', 46), ('🎉', 44), ('😩', 43), ('😍', 42), ('😭', 35), ('🙌', 32), ('❤', 31), ('😒', 25), ('👌', 21), ('😘', 19), ('😊', 16), ('🙏', 15), ('😔', 15), ('💰', 12), ('💙', 12), ('😁', 11), ('🙈', 10), ('😴', 10), ('😏', 10), ('💯', 9), ('👻', 9), ('💪', 9), ('😢', 9), ('✌', 9), ('😄', 8), ('💕', 8), ('🎈', 8), ('😋', 7), ('😎', 7), ('😫', 7), ('👏', 7), ('💗', 7), ('☺', 7), ('👊', 6), ('💀', 6), ('😻', 5), ('😅', 5), ('💜', 5), ('✨', 5), ('😜', 5), ('😤', 4), ('💃', 4), ('🍷', 4), ('👑', 4), ('💖', 4), ('🎁', 4), ('🎶', 4), ('♥', 4), ('💁', 4), ('👅', 4), ('😈', 3), ('😑', 3), ('✈', 3), ('😞', 3), ('🆘', 3), ('👀', 3), ('😳', 3), ('🎂', 3), ('🍕', 3), ('👯', 3), ('💋', 3), ('😹', 3), ('😉', 3), ('😪', 3), ('😌', 2), ('💏', 2), ('💸', 2), ('😡', 2), ('👭', 2), ('🎃', 2), ('🔀', 2), ('☝', 2), ('🎧', 2), ('🍹', 2), ('🐾', 2), ('😐', 2), ('🔥', 2), ('🌹', 2), ('🌸', 2), ('✋', 2), ('📖', 2), ('💩', 2), ('😬', 2), ('😣', 2), ('🔊', 2), ('✔', 2), ('🙊', 2), ('😀', 2), ('💛', 2), ('😷', 2), ('👍', 2), ('💆', 2), ('💤', 2), ('🎀', 2), ('☕', 2), ('🍸', 2), ('☀', 2), ('🔫', 2), ('😖', 2)]

# %% [markdown]
# ## Check difference in other features

# %%
old_group[old_group['description']=='']['name'].count()/old_group['name'].count()
# Out:
# 0.13500000000000001

# %%
young_group[young_group['description']=='']['name'].count()/young_group['name'].count()
# Out:
# 0.12768817204301075

# %%
age_joined.groupby(['is_18_25']).mean()
# Out:
#           contributors_enabled  default_profile  default_profile_image  \
# is_18_25
# False                      0.0         0.325000               0.010000
# True                       0.0         0.249328               0.002016
#
#           favourites_count  follow_request_sent  followers_count  following  \
# is_18_25
# False           744.805000                  0.0       730.205000        0.0
# True           1907.367608                  0.0      1024.581989        0.0
#
#           friends_count  geo_enabled        id_str  is_translation_enabled  \
# is_18_25
# False        479.750000     0.545000  5.496673e+08                0.000000
# True         781.183468     0.498656  7.047741e+08                0.000672
#
#           is_translator  listed_count  notifications  profile_background_tile  \
# is_18_25
# False               0.0      8.590000            0.0                 0.365000
# True                0.0      5.479839            0.0                 0.488575
#
#           profile_use_background_image  protected  statuses_count  \
# is_18_25
# False                         0.940000   0.010000    10047.245000
# True                          0.938172   0.014113    18147.575941
#
#             utc_offset  verified  status_contributors  status_favorite_count  \
# is_18_25
# False    -11260.150376       0.0                  NaN               0.297980
# True     -12681.973435       0.0                  NaN               0.270805
#
#              status_id  status_in_reply_to_status_id  \
# is_18_25
# False     5.142539e+17                  5.139603e+17
# True      5.148138e+17                  5.149130e+17
#
#           status_in_reply_to_user_id  status_retweet_count  status_0  \
# is_18_25
# False                   7.482404e+08             18.085859       NaN
# True                    6.200402e+08            344.877899       NaN
#
#           has_emoji  emoji_cnt  source_ios  source_android        Age  \
# is_18_25
# False       0.15500   0.355000    0.440000        0.155000  36.125000
# True        0.27621   0.624328    0.537634        0.193548  20.344758
#
#           description_length  has_description  older_group_words
# is_18_25
# False              69.770000         0.865000           0.185000
# True               51.064516         0.872312           0.077957

# %% [markdown]
# ## Data prep for modeling

# %%
# convert 'age_decade' into multiclass code
age_joined['age_idx'] = 1
age_joined['age_idx'][age_joined['age_decade'] == '18-25'] = 1
age_joined['age_idx'][age_joined['age_decade'] == '26-35'] = 2
age_joined['age_idx'][age_joined['age_decade'] == '36-45'] = 3
age_joined['age_idx'][age_joined['age_decade'] == '46-55'] = 4
age_joined['age_idx'][age_joined['age_decade'] == '>55'] = 5
# Out:
# //anaconda/envs/capstone/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# //anaconda/envs/capstone/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# //anaconda/envs/capstone/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# //anaconda/envs/capstone/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# //anaconda/envs/capstone/lib/python3.6/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df = age_joined[['emoji_cnt', 'source_android','statuses_count',
                     'has_description','followers_count', 'favourites_count',
                     'source_ios', 'has_emoji', 'older_group_words',
                     'is_translation_enabled', 'profile_background_tile',
                     'default_profile_image', 'age_idx']]

# %%
df.head()
# Out:
#            emoji_cnt  source_android  statuses_count  has_description  \
# 612815277          0               1           12230             True
# 490791079          1               0           14680             True
# 264416315          0               1           22857             True
# 97515432           0               0           71654             True
# 224078321          0               1           19888             True
#
#            followers_count  favourites_count  source_ios  has_emoji  \
# 612815277              274              7931           0          0
# 490791079              481              1141           1          1
# 264416315              878               174           0          0
# 97515432               742               303           0          0
# 224078321             1030              1188           0          0
#
#            older_group_words  is_translation_enabled  profile_background_tile  \
# 612815277              False                   False                     True
# 490791079              False                   False                    False
# 264416315              False                   False                     True
# 97515432               False                   False                     True
# 224078321              False                   False                     True
#
#            default_profile_image  age_idx
# 612815277                  False        1
# 490791079                  False        1
# 264416315                  False        1
# 97515432                   False        1
# 224078321                  False        1

# %% [markdown]
# ### Get the average age of a user's friends

# %%
friends = friends.set_index('FriendID')

# %%
ages_train = ages_train.set_index('ID')

# %%
friends_joined = friends.join(ages_train, how='inner')

# %%
friends_joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 27806334 to 2428918782
# Data columns (total 2 columns):
# ID     25 non-null int64
# Age    25 non-null int64
# dtypes: int64(2)
# memory usage: 600.0 bytes

# %%
friends_joined.ID.nunique()
# Out:
# 22

# %% [markdown]
# ### Proved not a viable to use a user's friends as a feature, too little data available
